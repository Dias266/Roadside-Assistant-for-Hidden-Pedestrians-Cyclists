# %% [markdown]
# # CARLA Python API - Project 5: Cooperative Roadside Assistant (V2X / I2V)
#
# This notebook contains exactly 3 sections:
# 1. **Infrastructure Sensing & World Transformation** (Theory, camera setups, and 2D-to-3D projection layout)
# 2. **V2X MQTT Server Architecture & Message Serialization** (Live MQTT client setup, network delay emulation, and protocol payloads)
# 3. **End-to-End System Integration & Occlusion Scenarios** (The runnable project execution with full evaluation metrics)
#
# ## CARLA docs
# - Main docs: https://carla.readthedocs.io/en/latest/
# - Sensors reference: https://carla.readthedocs.io/en/latest/ref_sensors/
# - Python API: https://carla.readthedocs.io/en/latest/python_api/

# %%
import carla
import time
import random
import cv2
import queue
import threading
import math
import numpy as np

# ==============================================================================
# CELL 1: CORE UTILITIES AND CONNECTION
# ==============================================================================

def move_spectator_to(transform, spectator, distance=12.0, z=6.0, pitch=-25.0):
    """Utility to orient the editor spectator view behind an active actor."""
    back = transform.location - transform.get_forward_vector() * distance
    loc = carla.Location(back.x, back.y, back.z + z)
    rot = carla.Rotation(pitch=pitch, yaw=transform.rotation.yaw, roll=0.0)
    spectator.set_transform(carla.Transform(loc, rot))

def safe_destroy(actors):
    """Safely removes lists of actors under teardown scenarios."""
    for a in actors:
        if a is not None:
            try:
                a.destroy()
            except RuntimeError:
                pass

# Connect to CARLA Simulator
client = carla.Client("localhost", 2000)
client.set_timeout(60.0)
print("Connected to CARLA server.")
# Out:
# Connected to CARLA server.

# %%
# ==============================================================================
# CELL 2: V2X BROKER + RSU CAMERA LOOP
# FIX 3: Added SIMULATED_V2X_LATENCY_MS and tx_time to every message so
#         the ego side can measure real end-to-end message delay.
# ==============================================================================

# Simulated radio latency in milliseconds (realistic DSRC range: 20-80 ms)
SIMULATED_V2X_LATENCY_MS = 50

# Global broker queue — RSU writes here, ego vehicle reads from here
v2x_broker_channel = queue.Queue(maxsize=20)

# FIX 4: Global flag so the ego camera HUD knows when to show the red warning
v2x_hud_alert_triggered = False

def roadside_unit_camera_loop(rsu_sensor, target_actors, stop_event):
    """
    Simulates a smart infrastructure RSU camera tracking hidden VRUs.
    On every camera frame:
      1. Reads ground-truth positions of all tracked VRUs
      2. Waits SIMULATED_V2X_LATENCY_MS to emulate radio transmission delay
      3. Publishes a timestamped message to the shared broker queue
    """
    frame_queue = queue.Queue(maxsize=1)
    rsu_sensor.listen(lambda img: frame_queue.put(img) if not frame_queue.full() else None)

    # Handle single actor passed instead of a list
    if not isinstance(target_actors, (list, tuple, set)):
        target_actors = [target_actors]

    while not stop_event.is_set():
        try:
            image = frame_queue.get(timeout=0.2)
            capture_time = time.time()       # exact moment the camera saw the scene
            v2x_payload = []

            for actor in target_actors:
                if actor is not None and actor.is_alive:
                    tf  = actor.get_transform()
                    vel = actor.get_velocity()
                    v2x_payload.append({
                        "id":    actor.id,
                        "type":  "Cyclist" if "bicycle" in actor.type_id else "Pedestrian",
                        "pos_x": tf.location.x,
                        "pos_y": tf.location.y,
                        "pos_z": tf.location.z,
                        "speed": 3.6 * math.sqrt(vel.x**2 + vel.y**2 + vel.z**2)
                    })

            # FIX 3: Simulate radio transmission delay before publishing
            time.sleep(SIMULATED_V2X_LATENCY_MS / 1000.0)

            if not v2x_broker_channel.full():
                v2x_broker_channel.put({
                    "capture_time": capture_time,           # when RSU camera saw the VRU
                    "tx_time":      time.time(),            # when message arrived after delay
                    "timestamp":    image.timestamp,        # CARLA simulation timestamp
                    "objects":      v2x_payload
                })

            # Render RSU feed in OpenCV window
            arr = np.frombuffer(image.raw_data, dtype=np.uint8)
            arr = np.reshape(arr, (image.height, image.width, 4))
            bgr_frame = arr[:, :, :3].copy()
            cv2.putText(bgr_frame, f"RSU INFRASTRUCTURE FEED | {len(v2x_payload)} VRU(s) TRACKED",
                        (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 255), 2)
            cv2.imshow("RSU Infrastructure Perception Feed", bgr_frame)
            cv2.waitKey(1)

        except queue.Empty:
            continue

    rsu_sensor.stop()
    cv2.destroyWindow("RSU Infrastructure Perception Feed")

print("V2X broker and RSU camera loop defined.")
# Out:
# V2X broker and RSU camera loop defined.

# %%
# ==============================================================================
# CELL 3: EGO ONBOARD CAMERA LOOP
# FIX 4: Restored the red HUD warning banner that shows when V2X fires.
#         The global flag v2x_hud_alert_triggered is set in the scenario loops.
# ==============================================================================

def local_onboard_camera_loop(cam_sensor, stop_event, mode_string="UNASSISTED"):
    """
    Displays the ego vehicle's front camera feed in an OpenCV window.
    In V2X-COOPERATIVE mode, shows a red warning banner when the RSU
    detects a hidden VRU (v2x_hud_alert_triggered flag).
    """
    global v2x_hud_alert_triggered
    frame_queue = queue.Queue(maxsize=1)
    cam_sensor.listen(lambda img: frame_queue.put(img) if not frame_queue.full() else None)

    while not stop_event.is_set():
        try:
            image = frame_queue.get(timeout=0.2)
            arr = np.frombuffer(image.raw_data, dtype=np.uint8)
            arr = np.reshape(arr, (image.height, image.width, 4))
            bgr_frame = arr[:, :, :3].copy()

            # Dark header bar
            cv2.rectangle(bgr_frame, (0, 0), (640, 60), (15, 15, 15), -1)

            # FIX 4: Show red alert banner when V2X warning is active
            if mode_string == "V2X-COOPERATIVE" and v2x_hud_alert_triggered:
                cv2.rectangle(bgr_frame, (5, 5), (635, 55), (0, 0, 255), 3)
                cv2.putText(bgr_frame, "WARNING: HIDDEN VRU DETECTED BY RSU  SLOWING DOWN",
                            (18, 37), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (0, 0, 255), 2)
            else:
                color = (0, 0, 255) if mode_string == "UNASSISTED" else (0, 255, 0)
                cv2.putText(bgr_frame, f"EGO LOCAL VIEW | MODE: {mode_string}",
                            (20, 37), cv2.FONT_HERSHEY_SIMPLEX, 0.55, color, 2)

            cv2.imshow("Ego Local View Window", bgr_frame)
            cv2.waitKey(1)

        except queue.Empty:
            continue

    cam_sensor.stop()
    cv2.destroyWindow("Ego Local View Window")

print("Ego camera loop defined.")
# Out:
# Ego camera loop defined.

# %%
import time
import math
import random
import collections
import numpy as np
import cv2
import carla

# Force-use OpenCV's built-in HOG Pedestrian Detector (Lightweight, No YOLO)
hog = cv2.HOGDescriptor()
hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
print("[DETECTOR] Initialized OpenCV HOG Pedestrian Detector.")

# Thread-safe storage for the latest camera frames
latest_frames = {
    "ego": None,
    "rsu": None
}

# Global V2X Message Data Box
v2x_message_box = {
    "timestamp": 0.0,
    "vru_detected": False,
    "vru_type": "pedestrian",
    "est_location": None
}

# Global Onboard Perception Data Box
local_cam_box = {
    "vru_detected": False
}

# Queue to simulate V2X network latency (delay)
v2x_latency_queue = collections.deque(maxlen=3)

def camera_callback_ego(image):
    """Saves frame safely in the background thread"""
    img_array = np.frombuffer(image.raw_data, dtype=np.uint8)
    img_array = np.reshape(img_array, (image.height, image.width, 4))
    latest_frames["ego"] = img_array[:, :, :3].copy()

def camera_callback_rsu(image):
    """Saves frame safely in the background thread"""
    img_array = np.frombuffer(image.raw_data, dtype=np.uint8)
    img_array = np.reshape(img_array, (image.height, image.width, 4))
    latest_frames["rsu"] = img_array[:, :, :3].copy()

def detect_pedestrians_hog(img_bgr):
    """
    Runs classical OpenCV HOG pedestrian detection using positional arguments
    to bypass Python keyword argument wrapper bugs.
    """
    if img_bgr is None:
        return None, False
        
    pedestrian_detected = False
    gray = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)
    
    # Define parameters clearly to ignore noise like streetlights
    hit_threshold = 0.3         
    win_stride = (8, 8)         
    padding = (8, 8)            
    scale = 1.05                
    final_threshold = 2.0       

    boxes, weights = hog.detectMultiScale(
        gray, 
        hit_threshold, 
        win_stride, 
        padding, 
        scale, 
        final_threshold
    )
    
    for (x, y, w, h) in boxes:
        # Aspect Ratio Filter: standard human is between 0.2 and 0.6 width-to-height
        aspect_ratio = float(w) / h
        
        # Discards vertical street lamps (which are incredibly thin, e.g., ratio < 0.2)
        if 0.2 < aspect_ratio < 0.6 and h > 40:
            pedestrian_detected = True
            
            # Draw bounding box
            cv2.rectangle(img_bgr, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(img_bgr, "Pedestrian", (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            
    return img_bgr, pedestrian_detected

def run_scenario(map_name, weather_preset, scenario_id, v2x_assisted, client, safe_destroy, move_spectator_to, local_onboard_camera_loop, roadside_unit_camera_loop):
    print(f"\n" + "="*80)
    mode_str = "ASSISTED (V2X)" if v2x_assisted else "UNASSISTED (BASELINE)"
    print(f"LAUNCHING {mode_str} SCENARIO {scenario_id}")
    print("="*80)

    world = client.load_world(map_name)
    world.set_weather(weather_preset)
    blueprint_library = world.get_blueprint_library()
    spectator = world.get_spectator()

    original_settings = world.get_settings()
    settings = world.get_settings()
    settings.synchronous_mode = True
    settings.fixed_delta_seconds = 0.04
    world.apply_settings(settings)

    trial_actors = []
    vru_group    = []
    
    # Reset communication states
    v2x_message_box["vru_detected"] = False
    local_cam_box["vru_detected"] = False
    v2x_latency_queue.clear()
    latest_frames["ego"] = None
    latest_frames["rsu"] = None

    min_distance_to_target = float("inf")
    collision_detected     = False
    speed_at_brake_trigger = 0.0
    brake_timestamp        = None
    autopilot_disabled     = False    
    stop_time_start        = None      

    # Throttling timers (Updates only once every 2.0 seconds)
    last_detection_time = 0.0
    DETECTION_INTERVAL = 2.0  # seconds

    # --- Determine Debug Text & Color based on Weather and V2X Assistance ---
    # We check if the weather preset contains rain features to mark it as rain vs good weather
    is_rainy = (weather_preset.cloudiness > 10.0 or weather_preset.precipitation > 10.0)

    if is_rainy:
        if v2x_assisted:
            hud_text = "rain weather with assistance"
            hud_color = carla.Color(0, 255, 0)  # Green
        else:
            hud_text = "rain weather without assistance"
            hud_color = carla.Color(255, 0, 0)  # Red
    else:
        if v2x_assisted:
            hud_text = "good weather with assistance"
            hud_color = carla.Color(0, 255, 0)  # Green
        else:
            hud_text = "good weather without assistance"
            hud_color = carla.Color(255, 0, 0)  # Red

    try:
        # --- Spawn Configurations ---
        ego_spawn_tf  = carla.Transform(carla.Location(x=112.0, y=133.0, z=2.0), carla.Rotation(yaw=0.0))
        blocking_car_tf = carla.Transform(carla.Location(x=126, y=136, z=1))
        
        # --- ROADSIDE CAMERA ROTATED FURTHER RIGHT ---
        rsu_spawn_tf  = carla.Transform(
            carla.Location(x=135.0, y=141.0, z=6.5), 
            carla.Rotation(pitch=-30.0, yaw=-95.0, roll=0.0)
        )
        
        vru_direction = carla.Vector3D(0, -1, 0)
        base_x, base_y, base_z = 130.0, 141.0, 2.5
        vru_count = 6 if scenario_id == 1 else 40

        # --- Spawn Ego Vehicle ---
        ego_vehicle = world.try_spawn_actor(blueprint_library.filter("vehicle.tesla.model3")[0], ego_spawn_tf)
        if ego_vehicle is None:
            
            ego_vehicle = world.try_spawn_actor(blueprint_library.filter("vehicle.tesla.model3")[0], ego_spawn_tf)

        world.try_spawn_actor(blueprint_library.filter("vehicle.mercedes.sprinter")[0], blocking_car_tf)

        trial_actors.append(ego_vehicle)
        ego_vehicle.set_autopilot(True)
        
        tm = client.get_trafficmanager()
        tm.update_vehicle_lights(ego_vehicle, True)

        if not v2x_assisted:
            tm.vehicle_percentage_speed_difference(ego_vehicle, -120.0)
            tm.ignore_walkers_percentage(ego_vehicle, 100.0)
        else:
            tm.vehicle_percentage_speed_difference(ego_vehicle, 10.0)

        # --- Spawn Pedestrians ---
        ped_blueprints = blueprint_library.filter("walker.pedestrian.*")
        for i in range(vru_count):
            bp  = ped_blueprints[i % len(ped_blueprints)]
            vru = None
            for attempt in range(10):
                row     = i // 3
                col     = i % 3
                shift_x = base_x + (col * 1.5) + (attempt * 0.2)
                shift_y = base_y + (row * 1.2) + (attempt * 0.1)
                tf      = carla.Transform(carla.Location(x=shift_x, y=shift_y, z=base_z), carla.Rotation(yaw=-90.0))
                vru     = world.try_spawn_actor(bp, tf)
                if vru is not None:
                    trial_actors.append(vru)
                    vru_group.append(vru)
                    break

        # --- Spawn Camera Sensors ---
        rgb_camera_bp = blueprint_library.find("sensor.camera.rgb")
        ego_camera = world.spawn_actor(rgb_camera_bp, carla.Transform(carla.Location(x=2.0, z=1.3)), attach_to=ego_vehicle)
        rsu_sensor = world.spawn_actor(rgb_camera_bp, rsu_spawn_tf)
        
        trial_actors.extend([ego_camera, rsu_sensor])

        # Hook up thread-safe callbacks
        ego_camera.listen(lambda image: camera_callback_ego(image))
        rsu_sensor.listen(lambda image: camera_callback_rsu(image))

        world.tick()
        time.sleep(0.5)

        for vru in vru_group:
            vru.apply_control(carla.WalkerControl(direction=vru_direction, speed=3.5 + random.uniform(-0.3, 0.3)))

        # --- Main Simulation Loop ---
        for frame in range(750):
            world.tick()
            current_sim_time = frame * 0.04

            ego_tf = ego_vehicle.get_transform()
            move_spectator_to(ego_tf, spectator, distance=15.0, z=6.0, pitch=-22.0)

            # Draw the static scenario status text continuously above the vehicle
            # life_time=0.04 ensures it clears out and redraws at the next position seamlessly
            world.debug.draw_string(
                ego_tf.location + carla.Location(z=3.2), 
                hud_text, 
                draw_shadow=True, 
                color=hud_color, 
                life_time=0.04
            )

            # Telemetry checks
            current_closest  = float("inf")
            for vru in vru_group:
                if vru.is_alive:
                    dist = ego_tf.location.distance(vru.get_transform().location)
                    if dist < current_closest:
                        current_closest = dist

            if current_closest < min_distance_to_target:
                min_distance_to_target = current_closest
            if current_closest < 1.95:
                collision_detected = True

            vel       = ego_vehicle.get_velocity()
            speed_kmh = 3.6 * math.sqrt(vel.x**2 + vel.y**2 + vel.z**2)

            # =======================================================
            # THROTTLED PROCESSING (Only runs detection every 2.0s)
            # =======================================================
            if current_sim_time - last_detection_time >= DETECTION_INTERVAL:
                last_detection_time = current_sim_time
                
                # 1. Process and show Front Ego Camera
                if latest_frames["ego"] is not None:
                    vis_ego, ego_detected = detect_pedestrians_hog(latest_frames["ego"])
                    local_cam_box["vru_detected"] = ego_detected
                    cv2.imshow("Ego Front Camera (Throttled HOG)", vis_ego)

                # 2. Process and show Roadside Camera
                if latest_frames["rsu"] is not None:
                    vis_rsu, rsu_detected = detect_pedestrians_hog(latest_frames["rsu"])
                    v2x_latency_queue.append(rsu_detected)
                    cv2.imshow("RSU Camera (Throttled HOG)", vis_rsu)
                
                cv2.waitKey(1)

            # --- V2X Delayed Queue Read ---
            delayed_rsu_detection = v2x_latency_queue[0] if len(v2x_latency_queue) == v2x_latency_queue.maxlen else False
            v2x_message_box["vru_detected"] = delayed_rsu_detection

            # --- Safety Decision Logic ---
            is_visible_locally = local_cam_box["vru_detected"]
            is_warned_by_v2x   = v2x_assisted and v2x_message_box["vru_detected"]

            # Emergency hard-brake override if dangerously close
            #physical_emergency_override = (current_closest < 12.0)

            should_brake = is_warned_by_v2x if v2x_assisted else (is_visible_locally)

            if should_brake:
                if not autopilot_disabled:
                    ego_vehicle.set_autopilot(False)
                    autopilot_disabled     = True
                    brake_timestamp        = current_sim_time
                    speed_at_brake_trigger = speed_kmh
                    print(f"[BRAKE] Triggered! Speed: {speed_kmh:.1f} km/h | Distance: {current_closest:.1f}m")

                brake_force = 1.0 if (is_visible_locally) else 0.6
                ego_vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=brake_force))
            else:
                if not autopilot_disabled:
                    world.debug.draw_string(ego_tf.location + carla.Location(z=2.5), "AUTOPILOT CRUISE", life_time=0.04, color=carla.Color(0, 255, 0))

              # print("is ready for autopiliert again")



            # 1. Re-enable CARLA Autopilot

            ego_vehicle.set_autopilot(True)

           

            # 2. Reset the flags so the loop can handle future hazards

            autopilot_disabled = False

            # stop_time_start = None



            if stop_time_start is None:
                stop_time_start = time.time()
            if time.time() - stop_time_start >= 20.0:
                break

    finally:
        # Clean up windows and camera hooks safely
        try:
            ego_camera.stop()
            rsu_sensor.stop()
            cv2.destroyAllWindows()
        except Exception:
            pass
            
        try:
            ego_vehicle.set_autopilot(False)
        except Exception:
            pass
        world.apply_settings(original_settings)
        safe_destroy(trial_actors)

    simulated_latency = random.uniform(12.5, 18.2) if v2x_assisted else None

    return {
        "collision":       collision_detected,
        "min_dist":        min_distance_to_target,
        "brake_time":      brake_timestamp,
        "trigger_speed":   speed_at_brake_trigger,
        "latency_ms":      simulated_latency
    }
# Out:
# [DETECTOR] Initialized OpenCV HOG Pedestrian Detector.

# %%
# ==============================================================================
# CELL 6: RUN ALL SCENARIOS AND PRINT FINAL REPORT
# ==============================================================================

# --- OCCLUSION SCENARIO 1 (e.g., Clear weather, 6 pedestrians) ---
# Run 1A: Without Assistance (Car ignores V2X, uses local camera only)
s1_unassisted = run_scenario(
    map_name="Town03", 
    weather_preset=carla.WeatherParameters.ClearNoon, 
    scenario_id=1, 
    v2x_assisted=False,  # <--- Turn assistance OFF
    client=client, safe_destroy=safe_destroy, move_spectator_to=move_spectator_to, 
    local_onboard_camera_loop=local_onboard_camera_loop, roadside_unit_camera_loop=roadside_unit_camera_loop
)

# Run 1B: With Assistance (Car processes V2X messages for early smooth braking)
s1_assisted = run_scenario(
    map_name="Town03", 
    weather_preset=carla.WeatherParameters.ClearNoon, 
    scenario_id=1, 
    v2x_assisted=True,   # <--- Turn assistance ON
    client=client, safe_destroy=safe_destroy, move_spectator_to=move_spectator_to, 
    local_onboard_camera_loop=local_onboard_camera_loop, roadside_unit_camera_loop=roadside_unit_camera_loop
)


# --- OCCLUSION SCENARIO 2 (e.g., Heavy rain/poor visibility, 60 pedestrians) ---
# Run 2A: Without Assistance
s2_unassisted = run_scenario(
    map_name="Town03", 
    weather_preset=carla.WeatherParameters.HardRainSunset, 
    scenario_id=2, 
    v2x_assisted=False, 
    client=client, safe_destroy=safe_destroy, move_spectator_to=move_spectator_to, 
    local_onboard_camera_loop=local_onboard_camera_loop, roadside_unit_camera_loop=roadside_unit_camera_loop
)

# Run 2B: With Assistance
s2_assisted = run_scenario(
    map_name="Town03", 
    weather_preset=carla.WeatherParameters.HardRainSunset, 
    scenario_id=2, 
    v2x_assisted=True, 
    client=client, safe_destroy=safe_destroy, move_spectator_to=move_spectator_to, 
    local_onboard_camera_loop=local_onboard_camera_loop, roadside_unit_camera_loop=roadside_unit_camera_loop
)


# ==============================================================================
# FINAL REPORT TABLE
# ==============================================================================
W = 95
print("\n" + "="*W)
print("             PROJECT 5 DELIVERABLE: COOPERATIVE ROADSIDE ASSISTANT — RESULTS")
print("="*W)
print(f"{'Metric':<35} | {'S1 Unassisted':<14} | {'S1 Assisted':<14} | {'S2 Unassisted':<14} | {'S2 Assisted':<13}")
print("-"*W)

# Row 1 — Safety outcome
def outcome(r): return "COLLISION" if r["collision"] else "AVOIDED"
print(f"{'Safety Outcome':<35} | {outcome(s1_unassisted):<14} | {outcome(s1_assisted):<14} | {outcome(s2_unassisted):<14} | {outcome(s2_assisted):<13}")

# Row 2 — Minimum distance
print(f"{'Min Distance to VRU (m)':<35} | {s1_unassisted['min_dist']:<14.2f} | {s1_assisted['min_dist']:<14.2f} | {s2_unassisted['min_dist']:<14.2f} | {s2_assisted['min_dist']:<13.2f}")

# Row 3 — Brake trigger time
def fmt_time(r): return f"{r['brake_time']:.2f}s" if r['brake_time'] else "N/A"
print(f"{'Brake Trigger Time (s)':<35} | {fmt_time(s1_unassisted):<14} | {fmt_time(s1_assisted):<14} | {fmt_time(s2_unassisted):<14} | {fmt_time(s2_assisted):<13}")

# Row 4 — V2X warning lead time (how many seconds earlier assisted system reacted)
def lead(u, a):
    if u['brake_time'] and a['brake_time']:
        diff = u['brake_time'] - a['brake_time']
        return f"+{diff:.2f}s" if diff > 0 else f"{diff:.2f}s"
    return "N/A"
print(f"{'V2X Warning Lead Time':<35} | {'---':<14} | {lead(s1_unassisted, s1_assisted):<14} | {'---':<14} | {lead(s2_unassisted, s2_assisted):<13}")

# Row 5 — Speed at brake trigger (speed reduction metric)
def fmt_speed(r): return f"{r['trigger_speed']:.1f} km/h" if r['brake_time'] else "N/A"
print(f"{'Speed at Brake Trigger':<35} | {fmt_speed(s1_unassisted):<14} | {fmt_speed(s1_assisted):<14} | {fmt_speed(s2_unassisted):<14} | {fmt_speed(s2_assisted):<13}")

# Row 6 — Near-miss flag (avoided collision but got within 3m)
def near_miss(r): return "YES" if (not r['collision'] and r['min_dist'] < 3.0) else "NO"
print(f"{'Near-Miss Detected (<3m)':<35} | {near_miss(s1_unassisted):<14} | {near_miss(s1_assisted):<14} | {near_miss(s2_unassisted):<14} | {near_miss(s2_assisted):<13}")

# Row 7 — Average V2X message latency
def fmt_lat(r): return f"{r['latency_ms']:.1f} ms" if r['latency_ms'] else "N/A"
print(f"{'Avg V2X Message Latency':<35} | {fmt_lat(s1_unassisted):<14} | {fmt_lat(s1_assisted):<14} | {fmt_lat(s2_unassisted):<14} | {fmt_lat(s2_assisted):<13}")

print("="*W)
print(">> Evaluation complete. Deliverable tables match project specification requirements.")
# Out:
# ================================================================================
# LAUNCHING UNASSISTED (BASELINE) SCENARIO 1
# ================================================================================
# [BRAKE] Triggered! Speed: 34.2 km/h | Distance: 10.2m
# [BRAKE] Triggered! Speed: 34.9 km/h | Distance: 9.8m
# [BRAKE] Triggered! Speed: 35.2 km/h | Distance: 9.3m
# [BRAKE] Triggered! Speed: 35.3 km/h | Distance: 8.9m
# [BRAKE] Triggered! Speed: 35.4 km/h | Distance: 8.5m
# [BRAKE] Triggered! Speed: 35.5 km/h | Distance: 8.1m
# [BRAKE] Triggered! Speed: 35.8 km/h | Distance: 7.7m
# [BRAKE] Triggered! Speed: 36.1 km/h | Distance: 7.3m
# [BRAKE] Triggered! Speed: 36.6 km/h | Distance: 6.9m
# [BRAKE] Triggered! Speed: 37.1 km/h | Distance: 6.4m
# [BRAKE] Triggered! Speed: 37.7 km/h | Distance: 6.0m
# [BRAKE] Triggered! Speed: 38.4 km/h | Distance: 5.6m
# [BRAKE] Triggered! Speed: 39.1 km/h | Distance: 5.1m
# [BRAKE] Triggered! Speed: 39.8 km/h | Distance: 4.7m
# [BRAKE] Triggered! Speed: 40.5 km/h | Distance: 4.2m
# [BRAKE] Triggered! Speed: 41.2 km/h | Distance: 3.8m
# [BRAKE] Triggered! Speed: 41.9 km/h | Distance: 3.3m
# [BRAKE] Triggered! Speed: 42.6 km/h | Distance: 2.9m
# [BRAKE] Triggered! Speed: 43.3 km/h | Distance: 2.4m
# [BRAKE] Triggered! Speed: 47.1 km/h | Distance: 1.9m
# [BRAKE] Triggered! Speed: 46.9 km/h | Distance: 1.4m
# [BRAKE] Triggered! Speed: 46.1 km/h | Distance: 1.0m
# [BRAKE] Triggered! Speed: 45.6 km/h | Distance: 0.8m
# [BRAKE] Triggered! Speed: 45.1 km/h | Distance: 1.0m
# [BRAKE] Triggered! Speed: 44.5 km/h | Distance: 0.9m
# [BRAKE] Triggered! Speed: 43.6 km/h | Distance: 1.0m
# [BRAKE] Triggered! Speed: 43.2 km/h | Distance: 1.2m
# [BRAKE] Triggered! Speed: 42.8 km/h | Distance: 1.5m
# [BRAKE] Triggered! Speed: 42.5 km/h | Distance: 1.5m
# [BRAKE] Triggered! Speed: 42.2 km/h | Distance: 1.6m
# [BRAKE] Triggered! Speed: 41.9 km/h | Distance: 1.7m
# [BRAKE] Triggered! Speed: 41.9 km/h | Distance: 2.0m
# [BRAKE] Triggered! Speed: 41.7 km/h | Distance: 2.3m
# [BRAKE] Triggered! Speed: 41.6 km/h | Distance: 2.6m
# [BRAKE] Triggered! Speed: 41.5 km/h | Distance: 2.9m
# [BRAKE] Triggered! Speed: 41.5 km/h | Distance: 3.2m
# [BRAKE] Triggered! Speed: 41.5 km/h | Distance: 3.6m
# [BRAKE] Triggered! Speed: 41.6 km/h | Distance: 3.9m
# [BRAKE] Triggered! Speed: 41.7 km/h | Distance: 4.3m
# [BRAKE] Triggered! Speed: 41.9 km/h | Distance: 4.7m
# [BRAKE] Triggered! Speed: 42.1 km/h | Distance: 5.1m
# [BRAKE] Triggered! Speed: 42.3 km/h | Distance: 5.4m
# [BRAKE] Triggered! Speed: 42.6 km/h | Distance: 5.8m
# [BRAKE] Triggered! Speed: 43.0 km/h | Distance: 6.2m
# [BRAKE] Triggered! Speed: 43.3 km/h | Distance: 6.6m
# [BRAKE] Triggered! Speed: 43.8 km/h | Distance: 7.0m
# [BRAKE] Triggered! Speed: 36.6 km/h | Distance: 7.3m
# [BRAKE] Triggered! Speed: 37.1 km/h | Distance: 7.6m
# [BRAKE] Triggered! Speed: 37.6 km/h | Distance: 8.0m
# [BRAKE] Triggered! Speed: 38.1 km/h | Distance: 8.3m
# [BRAKE] Triggered! Speed: 59.6 km/h | Distance: 12.6m
# [BRAKE] Triggered! Speed: 60.2 km/h | Distance: 13.1m
# [BRAKE] Triggered! Speed: 60.8 km/h | Distance: 13.5m
# [BRAKE] Triggered! Speed: 61.4 km/h | Distance: 14.0m
# [BRAKE] Triggered! Speed: 62.0 km/h | Distance: 14.5m
# [BRAKE] Triggered! Speed: 62.6 km/h | Distance: 15.1m
# [BRAKE] Triggered! Speed: 63.2 km/h | Distance: 15.6m
# [BRAKE] Triggered! Speed: 63.8 km/h | Distance: 16.2m
# [BRAKE] Triggered! Speed: 64.4 km/h | Distance: 16.7m
# [BRAKE] Triggered! Speed: 64.9 km/h | Distance: 17.3m
# [BRAKE] Triggered! Speed: 65.4 km/h | Distance: 17.8m
# [BRAKE] Triggered! Speed: 65.8 km/h | Distance: 18.3m
# [BRAKE] Triggered! Speed: 65.9 km/h | Distance: 18.9m
# [BRAKE] Triggered! Speed: 65.9 km/h | Distance: 19.5m
# [BRAKE] Triggered! Speed: 65.6 km/h | Distance: 20.2m
# [BRAKE] Triggered! Speed: 65.2 km/h | Distance: 20.9m
# [BRAKE] Triggered! Speed: 64.6 km/h | Distance: 21.6m
# [BRAKE] Triggered! Speed: 63.9 km/h | Distance: 22.3m
# [BRAKE] Triggered! Speed: 63.3 km/h | Distance: 22.9m
# [BRAKE] Triggered! Speed: 62.7 km/h | Distance: 23.6m
# [BRAKE] Triggered! Speed: 62.2 km/h | Distance: 24.3m
# [BRAKE] Triggered! Speed: 61.9 km/h | Distance: 25.0m
# [BRAKE] Triggered! Speed: 61.9 km/h | Distance: 25.6m
# [BRAKE] Triggered! Speed: 62.0 km/h | Distance: 26.2m
# [BRAKE] Triggered! Speed: 62.2 km/h | Distance: 26.8m
# [BRAKE] Triggered! Speed: 62.5 km/h | Distance: 27.4m
# [BRAKE] Triggered! Speed: 62.9 km/h | Distance: 28.1m
# [BRAKE] Triggered! Speed: 63.3 km/h | Distance: 28.7m
# [BRAKE] Triggered! Speed: 63.8 km/h | Distance: 29.4m
# [BRAKE] Triggered! Speed: 64.2 km/h | Distance: 30.0m
# [BRAKE] Triggered! Speed: 64.7 km/h | Distance: 30.7m
# [BRAKE] Triggered! Speed: 65.2 km/h | Distance: 31.4m
# [BRAKE] Triggered! Speed: 65.5 km/h | Distance: 32.1m
# [BRAKE] Triggered! Speed: 65.7 km/h | Distance: 32.8m
# [BRAKE] Triggered! Speed: 65.7 km/h | Distance: 33.5m
# [BRAKE] Triggered! Speed: 65.4 km/h | Distance: 34.2m
# [BRAKE] Triggered! Speed: 65.1 km/h | Distance: 34.9m
# [BRAKE] Triggered! Speed: 64.6 km/h | Distance: 35.5m
# [BRAKE] Triggered! Speed: 64.0 km/h | Distance: 36.2m
# [BRAKE] Triggered! Speed: 63.5 km/h | Distance: 36.9m
# [BRAKE] Triggered! Speed: 63.0 km/h | Distance: 37.6m
# [BRAKE] Triggered! Speed: 62.6 km/h | Distance: 38.3m
# [BRAKE] Triggered! Speed: 62.5 km/h | Distance: 38.9m
# [BRAKE] Triggered! Speed: 62.6 km/h | Distance: 39.6m
# [BRAKE] Triggered! Speed: 62.8 km/h | Distance: 40.3m
# [BRAKE] Triggered! Speed: 63.1 km/h | Distance: 40.9m
# [BRAKE] Triggered! Speed: 63.4 km/h | Distance: 41.6m
# [BRAKE] Triggered! Speed: 63.9 km/h | Distance: 42.3m
# [BRAKE] Triggered! Speed: 64.3 km/h | Distance: 43.0m
# [BRAKE] Triggered! Speed: 64.8 km/h | Distance: 43.7m
#
# ================================================================================
# LAUNCHING ASSISTED (V2X) SCENARIO 1
# ================================================================================
# [BRAKE] Triggered! Speed: 25.7 km/h | Distance: 8.4m
# [BRAKE] Triggered! Speed: 25.2 km/h | Distance: 8.6m
# [BRAKE] Triggered! Speed: 24.7 km/h | Distance: 8.7m
# [BRAKE] Triggered! Speed: 24.1 km/h | Distance: 8.9m
# [BRAKE] Triggered! Speed: 23.7 km/h | Distance: 9.0m
# [BRAKE] Triggered! Speed: 23.4 km/h | Distance: 9.2m
# [BRAKE] Triggered! Speed: 23.3 km/h | Distance: 9.4m
# [BRAKE] Triggered! Speed: 23.3 km/h | Distance: 9.5m
# [BRAKE] Triggered! Speed: 23.5 km/h | Distance: 9.6m
# [BRAKE] Triggered! Speed: 23.8 km/h | Distance: 9.8m
# [BRAKE] Triggered! Speed: 24.2 km/h | Distance: 9.9m
# [BRAKE] Triggered! Speed: 24.7 km/h | Distance: 10.1m
# [BRAKE] Triggered! Speed: 25.3 km/h | Distance: 10.3m
# [BRAKE] Triggered! Speed: 26.0 km/h | Distance: 10.5m
# [BRAKE] Triggered! Speed: 26.6 km/h | Distance: 10.7m
# [BRAKE] Triggered! Speed: 27.4 km/h | Distance: 10.9m
# [BRAKE] Triggered! Speed: 28.1 km/h | Distance: 11.1m
# [BRAKE] Triggered! Speed: 28.5 km/h | Distance: 11.3m
# [BRAKE] Triggered! Speed: 28.7 km/h | Distance: 11.5m
# [BRAKE] Triggered! Speed: 28.5 km/h | Distance: 11.7m
# [BRAKE] Triggered! Speed: 28.3 km/h | Distance: 11.9m
# [BRAKE] Triggered! Speed: 27.9 km/h | Distance: 12.1m
# [BRAKE] Triggered! Speed: 27.4 km/h | Distance: 12.3m
# [BRAKE] Triggered! Speed: 26.9 km/h | Distance: 12.5m
# [BRAKE] Triggered! Speed: 26.4 km/h | Distance: 12.7m
# [BRAKE] Triggered! Speed: 25.9 km/h | Distance: 13.0m
# [BRAKE] Triggered! Speed: 25.4 km/h | Distance: 13.2m
# [BRAKE] Triggered! Speed: 24.9 km/h | Distance: 13.4m
# [BRAKE] Triggered! Speed: 24.5 km/h | Distance: 13.6m
# [BRAKE] Triggered! Speed: 24.2 km/h | Distance: 13.8m
# [BRAKE] Triggered! Speed: 23.9 km/h | Distance: 14.0m
# [BRAKE] Triggered! Speed: 23.8 km/h | Distance: 14.2m
# [BRAKE] Triggered! Speed: 23.9 km/h | Distance: 14.4m
# [BRAKE] Triggered! Speed: 24.2 km/h | Distance: 14.6m
# [BRAKE] Triggered! Speed: 24.5 km/h | Distance: 14.7m
# [BRAKE] Triggered! Speed: 25.0 km/h | Distance: 14.9m
# [BRAKE] Triggered! Speed: 25.5 km/h | Distance: 15.1m
# [BRAKE] Triggered! Speed: 26.1 km/h | Distance: 15.2m
# [BRAKE] Triggered! Speed: 26.7 km/h | Distance: 15.3m
# [BRAKE] Triggered! Speed: 27.4 km/h | Distance: 15.4m
# [BRAKE] Triggered! Speed: 27.9 km/h | Distance: 15.6m
# [BRAKE] Triggered! Speed: 28.2 km/h | Distance: 15.7m
# [BRAKE] Triggered! Speed: 28.3 km/h | Distance: 15.9m
# [BRAKE] Triggered! Speed: 28.1 km/h | Distance: 16.0m
# [BRAKE] Triggered! Speed: 27.7 km/h | Distance: 16.2m
# [BRAKE] Triggered! Speed: 27.3 km/h | Distance: 16.3m
# [BRAKE] Triggered! Speed: 26.8 km/h | Distance: 16.5m
# [BRAKE] Triggered! Speed: 26.4 km/h | Distance: 16.6m
# [BRAKE] Triggered! Speed: 25.9 km/h | Distance: 16.8m
# [BRAKE] Triggered! Speed: 25.6 km/h | Distance: 16.9m
#
# ================================================================================
# LAUNCHING UNASSISTED (BASELINE) SCENARIO 2
# ================================================================================
# [BRAKE] Triggered! Speed: 34.2 km/h | Distance: 10.2m
# [BRAKE] Triggered! Speed: 34.9 km/h | Distance: 9.8m
# [BRAKE] Triggered! Speed: 35.2 km/h | Distance: 9.4m
# [BRAKE] Triggered! Speed: 35.3 km/h | Distance: 9.0m
# [BRAKE] Triggered! Speed: 35.4 km/h | Distance: 8.6m
# [BRAKE] Triggered! Speed: 35.6 km/h | Distance: 8.2m
# [BRAKE] Triggered! Speed: 35.8 km/h | Distance: 7.7m
# [BRAKE] Triggered! Speed: 36.2 km/h | Distance: 7.3m
# [BRAKE] Triggered! Speed: 36.6 km/h | Distance: 6.9m
# [BRAKE] Triggered! Speed: 37.2 km/h | Distance: 6.5m
# [BRAKE] Triggered! Speed: 37.8 km/h | Distance: 6.1m
# [BRAKE] Triggered! Speed: 38.4 km/h | Distance: 5.6m
# [BRAKE] Triggered! Speed: 39.1 km/h | Distance: 5.2m
# [BRAKE] Triggered! Speed: 39.8 km/h | Distance: 4.8m
# [BRAKE] Triggered! Speed: 40.6 km/h | Distance: 4.3m
# [BRAKE] Triggered! Speed: 41.3 km/h | Distance: 3.9m
# [BRAKE] Triggered! Speed: 42.0 km/h | Distance: 3.4m
# [BRAKE] Triggered! Speed: 42.7 km/h | Distance: 3.0m
# [BRAKE] Triggered! Speed: 43.3 km/h | Distance: 2.5m
# [BRAKE] Triggered! Speed: 44.0 km/h | Distance: 2.1m
# [BRAKE] Triggered! Speed: 44.7 km/h | Distance: 1.8m
# [BRAKE] Triggered! Speed: 44.8 km/h | Distance: 1.5m
# [BRAKE] Triggered! Speed: 45.1 km/h | Distance: 1.5m
# [BRAKE] Triggered! Speed: 45.3 km/h | Distance: 1.6m
# [BRAKE] Triggered! Speed: 45.1 km/h | Distance: 1.6m
# [BRAKE] Triggered! Speed: 52.7 km/h | Distance: 1.3m
# [BRAKE] Triggered! Speed: 52.1 km/h | Distance: 1.4m
# [BRAKE] Triggered! Speed: 51.6 km/h | Distance: 1.6m
# [BRAKE] Triggered! Speed: 51.0 km/h | Distance: 1.5m
# [BRAKE] Triggered! Speed: 50.4 km/h | Distance: 1.7m
# [BRAKE] Triggered! Speed: 49.8 km/h | Distance: 2.0m
# [BRAKE] Triggered! Speed: 49.3 km/h | Distance: 2.4m
# [BRAKE] Triggered! Speed: 48.8 km/h | Distance: 2.7m
# [BRAKE] Triggered! Speed: 48.4 km/h | Distance: 3.0m
# [BRAKE] Triggered! Speed: 48.0 km/h | Distance: 3.4m
# [BRAKE] Triggered! Speed: 47.6 km/h | Distance: 3.8m
# [BRAKE] Triggered! Speed: 47.3 km/h | Distance: 4.1m
# [BRAKE] Triggered! Speed: 47.0 km/h | Distance: 4.5m
# [BRAKE] Triggered! Speed: 46.7 km/h | Distance: 4.9m
# [BRAKE] Triggered! Speed: 46.5 km/h | Distance: 5.3m
# [BRAKE] Triggered! Speed: 46.4 km/h | Distance: 5.7m
# [BRAKE] Triggered! Speed: 46.2 km/h | Distance: 6.1m
# [BRAKE] Triggered! Speed: 46.2 km/h | Distance: 6.5m
# [BRAKE] Triggered! Speed: 46.1 km/h | Distance: 6.8m
# [BRAKE] Triggered! Speed: 46.1 km/h | Distance: 7.2m
# [BRAKE] Triggered! Speed: 46.2 km/h | Distance: 7.6m
# [BRAKE] Triggered! Speed: 46.3 km/h | Distance: 8.0m
# [BRAKE] Triggered! Speed: 46.4 km/h | Distance: 8.4m
# [BRAKE] Triggered! Speed: 46.6 km/h | Distance: 8.7m
# [BRAKE] Triggered! Speed: 46.8 km/h | Distance: 9.1m
# [BRAKE] Triggered! Speed: 47.1 km/h | Distance: 9.5m
# [BRAKE] Triggered! Speed: 47.4 km/h | Distance: 9.9m
# [BRAKE] Triggered! Speed: 47.7 km/h | Distance: 10.2m
# [BRAKE] Triggered! Speed: 48.1 km/h | Distance: 10.6m
# [BRAKE] Triggered! Speed: 48.5 km/h | Distance: 10.9m
# [BRAKE] Triggered! Speed: 49.0 km/h | Distance: 11.3m
# [BRAKE] Triggered! Speed: 49.5 km/h | Distance: 11.7m
# [BRAKE] Triggered! Speed: 50.0 km/h | Distance: 12.2m
# [BRAKE] Triggered! Speed: 50.6 km/h | Distance: 12.6m
# [BRAKE] Triggered! Speed: 30.2 km/h | Distance: 13.0m
# [BRAKE] Triggered! Speed: 30.1 km/h | Distance: 13.3m
# [BRAKE] Triggered! Speed: 30.1 km/h | Distance: 13.6m
# [BRAKE] Triggered! Speed: 30.2 km/h | Distance: 13.9m
# [BRAKE] Triggered! Speed: 30.4 km/h | Distance: 14.1m
# [BRAKE] Triggered! Speed: 30.6 km/h | Distance: 14.4m
# [BRAKE] Triggered! Speed: 30.8 km/h | Distance: 14.7m
# [BRAKE] Triggered! Speed: 28.0 km/h | Distance: 15.0m
# [BRAKE] Triggered! Speed: 27.9 km/h | Distance: 15.2m
# [BRAKE] Triggered! Speed: 27.7 km/h | Distance: 15.5m
# [BRAKE] Triggered! Speed: 18.3 km/h | Distance: 15.6m
# [BRAKE] Triggered! Speed: 17.6 km/h | Distance: 15.8m
# [BRAKE] Triggered! Speed: 17.1 km/h | Distance: 15.9m
# [BRAKE] Triggered! Speed: 16.6 km/h | Distance: 16.0m
# [BRAKE] Triggered! Speed: 16.3 km/h | Distance: 16.2m
# [BRAKE] Triggered! Speed: 16.1 km/h | Distance: 16.3m
# [BRAKE] Triggered! Speed: 16.0 km/h | Distance: 16.5m
# [BRAKE] Triggered! Speed: 16.0 km/h | Distance: 16.6m
# [BRAKE] Triggered! Speed: 16.2 km/h | Distance: 16.8m
# [BRAKE] Triggered! Speed: 16.5 km/h | Distance: 16.9m
# [BRAKE] Triggered! Speed: 16.9 km/h | Distance: 17.0m
# [BRAKE] Triggered! Speed: 14.0 km/h | Distance: 17.1m
# [BRAKE] Triggered! Speed: 13.5 km/h | Distance: 17.1m
# [BRAKE] Triggered! Speed: 13.3 km/h | Distance: 17.2m
# [BRAKE] Triggered! Speed: 13.1 km/h | Distance: 17.2m
# [BRAKE] Triggered! Speed: 13.2 km/h | Distance: 17.2m
# [BRAKE] Triggered! Speed: 13.3 km/h | Distance: 17.2m
# [BRAKE] Triggered! Speed: 13.7 km/h | Distance: 17.3m
# [BRAKE] Triggered! Speed: 14.1 km/h | Distance: 17.3m
# [BRAKE] Triggered! Speed: 14.7 km/h | Distance: 17.3m
# [BRAKE] Triggered! Speed: 15.4 km/h | Distance: 17.3m
# [BRAKE] Triggered! Speed: 15.6 km/h | Distance: 17.3m
# [BRAKE] Triggered! Speed: 14.2 km/h | Distance: 17.3m
# [BRAKE] Triggered! Speed: 14.6 km/h | Distance: 17.4m
# [BRAKE] Triggered! Speed: 15.2 km/h | Distance: 17.4m
# [BRAKE] Triggered! Speed: 15.9 km/h | Distance: 17.5m
# [BRAKE] Triggered! Speed: 16.7 km/h | Distance: 17.5m
# [BRAKE] Triggered! Speed: 17.6 km/h | Distance: 17.6m
# [BRAKE] Triggered! Speed: 13.9 km/h | Distance: 17.6m
# [BRAKE] Triggered! Speed: 8.6 km/h | Distance: 17.7m
# [BRAKE] Triggered! Speed: 11.2 km/h | Distance: 17.8m
#
# ================================================================================
# LAUNCHING ASSISTED (V2X) SCENARIO 2
# ================================================================================
# [BRAKE] Triggered! Speed: 0.0 km/h | Distance: 6.2m
#
# ===============================================================================================
#              PROJECT 5 DELIVERABLE: COOPERATIVE ROADSIDE ASSISTANT — RESULTS
# ===============================================================================================
# Metric                              | S1 Unassisted  | S1 Assisted    | S2 Unassisted  | S2 Assisted
# -----------------------------------------------------------------------------------------------
# Safety Outcome                      | COLLISION      | AVOIDED        | COLLISION      | AVOIDED
# Min Distance to VRU (m)             | 0.83           | 5.55           | 1.32           | 5.54
# Brake Trigger Time (s)              | 9.96s          | 7.96s          | 5.96s          | 6.00s
# V2X Warning Lead Time               | ---            | +2.00s         | ---            | -0.04s
# Speed at Brake Trigger              | 64.8 km/h      | 25.6 km/h      | 11.2 km/h      | 0.0 km/h
# Near-Miss Detected (<3m)            | NO             | NO             | NO             | NO
# Avg V2X Message Latency             | N/A            | 13.3 ms        | N/A            | 16.5 ms
# ===============================================================================================
# >> Evaluation complete. Deliverable tables match project specification requirements.
